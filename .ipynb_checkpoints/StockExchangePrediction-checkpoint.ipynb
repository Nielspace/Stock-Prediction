# %%
import pandas as pd
# %matplotlib inline

# %%
data = pd.read_csv('data/AAPL.csv')

# %%
data.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-08-01  199.130005  201.759995  197.309998  201.500000  198.478760
# 1  2018-08-02  200.580002  208.380005  200.350006  207.389999  204.280457
# 2  2018-08-03  207.029999  208.740005  205.479996  207.990005  204.871445
# 3  2018-08-06  208.000000  209.250000  207.070007  209.070007  205.935257
# 4  2018-08-07  209.320007  209.500000  206.759995  207.110001  204.004639
#
#      Volume
# 0  67935700
# 1  62404000
# 2  33447400
# 3  25425400
# 4  25587400

# %%
data['Date'].dtype
# Out:
# dtype('O')

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
data['Date'].plot(figsize=(10,8))

# %%
data.Close.describe()
# Out:
# count    251.000000
# mean     193.168566
# std       21.883909
# min      142.190002
# 25%      174.794998
# 50%      197.179993
# 75%      209.110001
# max      232.070007
# Name: Close, dtype: float64

# %%
import matplotlib.pyplot as plt
import datetime


plt.figure(figsize=(14, 5), dpi=100)
plt.plot(data['Date'], data['Close'], label='Stock')
# plt.vlines(datetime.date(2018,6,13), 0, 27000, linestyles='--', colors='gray', label='Train/Test data cut-off')
plt.xlabel('Date')
plt.ylabel('USD')
plt.title('Figure 1: Stock price')
plt.legend()
plt.show()

# %%
num_training_days = int(data.shape[0]*.7)
print('Number of training days: {}. Number of test days: {}.'.format(num_training_days, \
                                                                    data.shape[0]-num_training_days))
# Out:
# Number of training days: 175. Number of test days: 76.

# %%
# creating Technical points or RSI relative strength index

data_stock = data[['Date', 'Close']]

rsi_period = 14
chg = data['Close'].diff(1)
gain = chg.mask(chg<0,0)
loss = chg.mask(chg>0,0)
avg_gain = gain.ewm(com=rsi_period-1,min_periods=rsi_period).mean()
avg_loss = loss.ewm(com=rsi_period-1,min_periods=rsi_period).mean()

rs = abs(avg_gain/avg_loss)
rsi = 100 - (100/(1+rs))

"""ps: when the rsi is below 30 it is considered oversold 
   and if it is over 70 it is considered overbought"""

# data_stock['gain'] = gain
# data_stock['loss'] = loss
# data_stock['avg_gain'] = avg_gain
# data_stock['avg_loss'] = avg_loss


#moving average 
data_stock['ma7'] = data['Close'].rolling(window=7).mean()
data_stock['ma21'] = data['Close'].rolling(window=21).mean()

#Exponential Moving average
data_stock['ema'] = data_stock['Close'].ewm(com=0.5).mean()

#Bollinger Bands
std = data_stock.Close.rolling(20).std()
data_stock['upperBand'] = data_stock['ma21'] + (std*2)
data_stock['lowerBand'] = data_stock['ma21'] - (std*2)


# Momentum
data_stock['momentum'] = data_stock['Close']-1

#MACD
exp1 = data_stock.Close.ewm(span=26).mean()
exp2 = data_stock.Close.ewm(span=12).mean()
data_stock['macd'] = exp2-exp1
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data_stock.head(10)
# Out:
#         Date       Close         ma7  ma21         ema  upperBand  lowerBand  \
# 0 2018-08-01  201.500000         NaN   NaN  201.500000        NaN        NaN
# 1 2018-08-02  207.389999         NaN   NaN  205.917499        NaN        NaN
# 2 2018-08-03  207.990005         NaN   NaN  207.352311        NaN        NaN
# 3 2018-08-06  209.070007         NaN   NaN  208.511756        NaN        NaN
# 4 2018-08-07  207.110001         NaN   NaN  207.573391        NaN        NaN
# 5 2018-08-08  207.250000         NaN   NaN  207.357501        NaN        NaN
# 6 2018-08-09  208.880005  207.027145   NaN  208.372968        NaN        NaN
# 7 2018-08-10  207.529999  207.888574   NaN  207.810903        NaN        NaN
# 8 2018-08-13  208.869995  208.100002   NaN  208.517000        NaN        NaN
# 9 2018-08-14  209.750000  208.351430   NaN  209.339014        NaN        NaN
#
#      momentum      macd
# 0  200.500000  0.000000
# 1  206.389999  0.132147
# 2  206.990005  0.186988
# 3  208.070007  0.246341
# 4  206.110001  0.195414
# 5  206.250000  0.167113
# 6  207.880005  0.219926
# 7  206.529999  0.187597
# 8  207.869995  0.228838
# 9  208.750000  0.300092

# %%
data_stock.ma7[:1]
# Out:
# 0   NaN
# Name: ma7, dtype: float64

# %%
def plot_technical_indicators(dataset, last_days):
    plt.figure(figsize=(16, 10), dpi=100)
    shape_0 = dataset.shape[0]
    xmacd_ = shape_0-last_days
    
    dataset = dataset.iloc[-last_days:, :]
    x_ = range(3, dataset.shape[0])
    x_ =list(dataset.index)
    
    # Plot first subplot
    plt.subplot(2, 1, 1)
    plt.plot(dataset['ma7'],label='MA 7', color='g',linestyle='--')
    plt.plot(dataset['Close'],label='Closing Price', color='b')
    plt.plot(dataset['ma21'],label='MA 21', color='r',linestyle='--')
    plt.plot(dataset['upperBand'],label='Upper Band', color='c')
    plt.plot(dataset['lowerBand'],label='Lower Band', color='c')
    plt.fill_between(x_, dataset['lowerBand'], dataset['upperBand'], alpha=0.35)
    plt.title('Technical indicators for Apple Inc - last {} days.'.format(last_days))
    plt.ylabel('USD')
    plt.legend()

    # Plot second subplot
    plt.subplot(2, 1, 2)
    plt.title('MACD')
    plt.plot(dataset['macd'],label='MACD', linestyle='-.')
    plt.hlines(15, xmacd_, shape_0, colors='g', linestyles='--')
    plt.hlines(-15, xmacd_, shape_0, colors='g', linestyles='--')
#     plt.plot(dataset['log_momentum'],label='Momentum', color='b',linestyle='-')

    plt.legend()
    plt.show()

# %%
plot_technical_indicators(data_stock, 200)

# %%
data_stock.tail()
# Out:
#           Date       Close         ma7        ma21         ema   upperBand  \
# 246 2019-07-25  207.020004  206.192858  203.475239  207.481711  209.312177
# 247 2019-07-26  207.740005  206.820001  203.853335  207.653907  209.655835
# 248 2019-07-29  209.679993  207.394285  204.326667  209.004631  209.888210
# 249 2019-07-30  208.779999  208.278571  204.843810  208.854876  210.496900
# 250 2019-07-31  213.039993  209.109998  205.390953  211.644954  211.973165
#
#       lowerBand    momentum      macd
# 246  197.638302  206.020004  3.144991
# 247  198.050835  206.740005  3.105760
# 248  198.765125  208.679993  3.194387
# 249  199.190721  207.779999  3.155627
# 250  198.808740  212.039993  3.429126

# %% [markdown]
# # Fast Fourier Transform - FFT

# %%
import numpy as np

# %%
fourier_transform = np.fft.fft(np.array(data_stock['Close'].tolist()))
fourier_df = pd.DataFrame({'fourier':fourier_transform})
fourier_df['absolute'] = fourier_df['fourier'].apply(lambda x: np.abs(x))
fourier_df['angle'] = fourier_df['fourier'].apply(lambda x: np.angle(x))

# %%
fourier_df.head()
# Out:
#                                      fourier      absolute     angle
# 0                     (48485.31008200002+0j)  48485.310082  0.000000
# 1    (2955.4189309674975-579.1742629913748j)   3011.634753 -0.193518
# 2  (-1204.7124072969543-1795.0783081231955j)   2161.859874 -2.161875
# 3   (193.09724616408624+367.27734543564816j)    414.944810  1.086759
# 4    (369.81092138729565+308.3138076975683j)    481.474321  0.694959

# %%
plt.figure(figsize=(14, 7), dpi=100)
plt.subplot(2,1,1)
fft_list = np.asarray(fourier_df['fourier'].tolist())
for num_ in [10,30]:
    fft_list_m10= np.copy(fft_list); fft_list_m10[num_:-num_]=0
#     print(fft_list_m10)
    plt.plot(np.fft.ifft(fft_list_m10), label='Fourier transform with {} components'.format(num_))
plt.plot(data_stock['Close'],  label='Real')
plt.xlabel('Days')
plt.ylabel('USD')
# plt.title('Figure 3: Apple Inc(close) stock prices & Fourier transforms')
plt.legend()
plt.show()

plt.figure(figsize=(14, 7), dpi=100)
plt.subplot(2,1,2)
fft_list = np.asarray(fourier_df['fourier'].tolist())
for num_ in [10,25,45]:
    fft_list_m10= np.copy(fft_list); fft_list_m10[num_:-num_]=0
    plt.plot(np.fft.ifft(fft_list_m10), label='Fourier transform with {} components'.format(num_))
plt.plot(data_stock['Close'],  label='Real')
plt.xlabel('Days')
plt.ylabel('USD')
# plt.title('Figure 3: Apple Inc(close) stock prices & Fourier transforms')
plt.legend()
plt.show()

# %%
print('Total dataset has {} samples, and {} features.'.format(data_stock.shape[0], \
                                                              data_stock.shape[1]))
# Out:
# Total dataset has 251 samples, and 9 features.

# %%
def get_feature_importance_data(data):
    data = data.copy()
    y = data['Close']
    X = data.iloc[:, 1:]
    
    train_samples = int(X.shape[0] * 0.65)
 
    X_train = X.iloc[:train_samples]
    X_test = X.iloc[train_samples:]

    y_train = y.iloc[:train_samples]
    y_test = y.iloc[train_samples:]
    
    return (X_train, y_train), (X_test, y_test)

# %%
from sklearn.impute import SimpleImputer
impute = SimpleImputer(strategy='median')
dataImpute = data_stock.interpolate(method='linear', limit_direction='forward', axis=0)

# %%
data_impute = data_stock.dropna(axis=1)

# %%
data_impute.head()
# Out:
#         Date       Close         ema    momentum      macd
# 0 2018-08-01  201.500000  201.500000  200.500000  0.000000
# 1 2018-08-02  207.389999  205.917499  206.389999  0.132147
# 2 2018-08-03  207.990005  207.352311  206.990005  0.186988
# 3 2018-08-06  209.070007  208.511756  208.070007  0.246341
# 4 2018-08-07  207.110001  207.573391  206.110001  0.195414

# %%
(X_train, y_train), (X_test, y_test) = get_feature_importance_data(data_impute)

# %%
from sklearn.ensemble import RandomForestRegressor
forr = RandomForestRegressor()
forr.fit(X_train, y_train)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
forr.score(X_train, y_train)
# Out:
# 0.999835056787701

# %%
forr.feature_importances_
# Out:
# array([3.03725914e-01, 1.93557723e-01, 5.02486378e-01, 2.29985274e-04])

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_train, forr.predict(X_train))
# Out:
# 0.11104826240800231

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(forr, X_train, y_train, cv=5, scoring='neg_mean_squared_error')
# Out:
# array([ -0.41849902,  -1.88395617, -21.24684629, -30.66764685,
#         -0.61699902])

# %%
fig = plt.figure(figsize=(8,8))
plt.xticks(rotation='vertical')
plt.bar([i for i in range(len(forr.feature_importances_))], forr.feature_importances_.tolist(), 
        tick_label=X_test.columns)
plt.title('Figure 6: Feature importance of the technical indicators.')
plt.show()

# %%
from statsmodels.tsa.arima_model import ARIMA
stock = data_stock['Close']
model = ARIMA(stock, order=(3,1,0))
model_fit = model.fit(disp=1)
print(model_fit.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.Close   No. Observations:                  250
# Model:                 ARIMA(3, 1, 0)   Log Likelihood                -675.245
# Method:                       css-mle   S.D. of innovations              3.604
# Date:                Thu, 01 Aug 2019   AIC                           1360.489
# Time:                        16:07:20   BIC                           1378.097
# Sample:                             1   HQIC                          1367.576
#
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0416      0.203      0.205      0.838      -0.356       0.439
# ar.L1.D.Close    -0.0466      0.064     -0.733      0.465      -0.171       0.078
# ar.L2.D.Close    -0.0582      0.063     -0.917      0.360      -0.183       0.066
# ar.L3.D.Close    -0.0201      0.063     -0.317      0.751      -0.144       0.104
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            0.8907           -3.1368j            3.2608           -0.2060
# AR.2            0.8907           +3.1368j            3.2608            0.2060
# AR.3           -4.6694           -0.0000j            4.6694           -0.5000
# -----------------------------------------------------------------------------

# %%
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(stock)
plt.figure(figsize=(10, 7), dpi=80)
plt.show()

# %%
from pandas import read_csv
from pandas import datetime
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error

X = stock.values
size = int(len(X) * 0.4)
train, test = X[0:150], X[150:]

history = [x for x in train]
predictions = []
for t in range(len(test)):
    model = ARIMA(history, order=(7,1,0))
    model_fit = model.fit(solver = 'newton')
    output = model_fit.forecast(steps = 10)
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
# Out:
# Optimization terminated successfully.
#          Current function value: 2.774533
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.771196
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.776026
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.773734
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.771005
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.769617
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.768670
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.766791
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.764148
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.761034
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.766851
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.766802
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.764945
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.763410
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.760499
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.757435
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.754511
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.751553
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.752053
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.750102
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.747353
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.744708
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.743750
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.740934
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.738211
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.736289
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.733456
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.730603
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.727808
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.727250
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.724693
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.722100
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.721808
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.719050
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.717019
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.714652
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.712052
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.713267
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.727483
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.725228
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.724780
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.723209
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.725987
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.723491
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.722180
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.725982
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.748235
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.746416
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.744892
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.742365
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.739886
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.741241
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.741670
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.740067
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.740144
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.737950
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.735543
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.733212
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.731540
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.731131
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.728897
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.734310
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.733827
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.733508
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.736944
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.736138
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.735182
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.732894
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.730817
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.729365
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.727096
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.726891
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.724720
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.722864
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.720636
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.718401
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.717784
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.717888
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.715802
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.713998
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.713729
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.711926
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.710289
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.708149
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.709541
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.707527
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.705937
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.704536
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.702731
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.701221
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.699153
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.697114
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.695708
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.695499
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.696874
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.695129
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.693083
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.691401
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.689496
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.687760
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 2.685811
#          Iterations 4

# %%
yhat[0]
# Out:
# 209.5001790154596

# %%
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)
# Out:
# Test MSE: 9.250

# %%
plt.figure(figsize=(12, 6), dpi=100)
plt.plot(test, label='Real')
plt.plot(predictions, color='red', label='Predicted')
plt.xlabel('Days')
plt.ylabel('USD')
# plt.title('Figure 5: ARIMA model on Apple Inc stock')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6), dpi=100)
plt.plot(test, label='Real')
plt.plot(predictions, color='red', label='Predicted')
plt.xlabel('Days')
plt.ylabel('USD')
# plt.title('Figure 5: ARIMA model on Apple Inc stock')
plt.legend()
plt.show()

# %%
import math 

def gelu(x):
    return 0.5 * x * (1 + math.tanh(math.sqrt(2 / math.pi) * (x + 0.044715 * math.pow(x, 3))))
def relu(x):
    return max(x, 0)
def lrelu(x):
    return max(0.01*x, x)

# %%
plt.figure(figsize=(15, 5))
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=.5, hspace=None)

ranges_ = (-10, 3, .25)

plt.subplot(1, 2, 1)
plt.plot([i for i in np.arange(*ranges_)], [relu(i) for i in np.arange(*ranges_)], label='ReLU', marker='.')
plt.plot([i for i in np.arange(*ranges_)], [gelu(i) for i in np.arange(*ranges_)], label='GELU')
plt.hlines(0, -10, 3, colors='gray', linestyles='--', label='0')
plt.title('Figure 7: GELU as an activation function for autoencoders')
plt.ylabel('f(x) for GELU and ReLU')
plt.xlabel('x')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot([i for i in np.arange(*ranges_)], [lrelu(i) for i in np.arange(*ranges_)], label='Leaky ReLU')
plt.hlines(0, -10, 3, colors='gray', linestyles='--', label='0')
plt.ylabel('f(x) for Leaky ReLU')
plt.xlabel('x')
plt.title('Figure 8: LeakyReLU')
plt.legend()

plt.show()

# %%
import torch

# %%
data_index = data.set_index('Date')

# %%
data_index.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-08-01  199.130005  201.759995  197.309998  201.500000  198.478760
# 2018-08-02  200.580002  208.380005  200.350006  207.389999  204.280457
# 2018-08-03  207.029999  208.740005  205.479996  207.990005  204.871445
# 2018-08-06  208.000000  209.250000  207.070007  209.070007  205.935257
# 2018-08-07  209.320007  209.500000  206.759995  207.110001  204.004639
#
#               Volume
# Date
# 2018-08-01  67935700
# 2018-08-02  62404000
# 2018-08-03  33447400
# 2018-08-06  25425400
# 2018-08-07  25587400

# %%
data_index.Close.plot(figsize=(10,8))

# %%
from pandas import read_csv
from pandas import datetime
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error

X = data_index.Close.values
size = int(len(X) * 0.7)
train, test = X[0:150], X[150:]

history = [x for x in train]
predictions = []
for t in range(len(test)):
    model = ARIMA(history, order=(5,1,0))
    model_fit = model.fit()
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)

# %%
len(test)
len(train)
# Out:
# 150

# %%
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)
# Out:
# Test MSE: 9.082

# %%
plt.figure(figsize=(12, 6), dpi=100)
plt.plot(test, label='Real')
plt.plot(predictions, color='red', label='Predicted')
plt.xlabel('Days')
plt.ylabel('USD')
# plt.title('Figure 5: ARIMA model on Apple Inc stock')
plt.legend()
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
ran_forr = RandomForestRegressor()

# %%
date = np.array(data_index.index).reshape(-1,1)

# %%
ran_forr.fit(date, data_index.Close)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
ran_forr.score(date, data_index.Close)
# Out:
# 0.9962996732415027

# %%
ran_forr.predict(date)[0]
# Out:
# 203.31300040000002

# %%
data_index.Close[0]
# Out:
# 201.5

# %%
mean_squared_error(ran_forr.predict, data_index.Close)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-200-114666b50d2b> in <module>
# ----> 1 mean_squared_error(ran_forr.predict, data_index.Close)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/metrics/regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput)
#     239     """
#     240     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 241         y_true, y_pred, multioutput)
#     242     check_consistent_length(y_true, y_pred, sample_weight)
#     243     output_errors = np.average((y_true - y_pred) ** 2, axis=0,
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/metrics/regression.py in _check_reg_targets(y_true, y_pred, multioutput)
#      75
#      76     """
# ---> 77     check_consistent_length(y_true, y_pred)
#      78     y_true = check_array(y_true, ensure_2d=False)
#      79     y_pred = check_array(y_pred, ensure_2d=False)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     199     """
#     200
# --> 201     lengths = [_num_samples(X) for X in arrays if X is not None]
#     202     uniques = np.unique(lengths)
#     203     if len(uniques) > 1:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/validation.py in <listcomp>(.0)
#     199     """
#     200
# --> 201     lengths = [_num_samples(X) for X in arrays if X is not None]
#     202     uniques = np.unique(lengths)
#     203     if len(uniques) > 1:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/validation.py in _num_samples(x)
#     140         else:
#     141             raise TypeError("Expected sequence or array-like, got %s" %
# --> 142                             type(x))
#     143     if hasattr(x, 'shape'):
#     144         if len(x.shape) == 0:
#
# TypeError: Expected sequence or array-like, got <class 'method'>
